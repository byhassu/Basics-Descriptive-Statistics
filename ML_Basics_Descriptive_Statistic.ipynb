# %%
import pandas as pd

# %%
data=pd.read_csv('/content/pima-indians-diabetes.csv')
data.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
no_head=pd.read_csv('/content/diabetes.csv',header=None)

# %%
no_head
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
no_head[0:2]
# Out:
#    0    1   2   3  4     5      6   7  8
# 0  6  148  72  35  0  33.6  0.627  50  1
# 1  1   85  66  29  0  26.6  0.351  31  0

# %% [markdown]
# ## datasete with manually columns name

# %%
data_name=pd.read_csv('/content/diabetes.csv',names=['header1','header2','header3','header4','header5','header6','header7','header8',])

# %%
data_name
# Out:
#      header1  header2  header3  header4  header5  header6  header7  header8  \
# 0          6      148       72       35        0     33.6    0.627       50
# 1          1       85       66       29        0     26.6    0.351       31
# 2          8      183       64        0        0     23.3    0.672       32
# 3          1       89       66       23       94     28.1    0.167       21
# 4          0      137       40       35      168     43.1    2.288       33
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 763       10      101       76       48      180     32.9    0.171       63
# 764        2      122       70       27        0     36.8    0.340       27
# 765        5      121       72       23      112     26.2    0.245       30
# 766        1      126       60        0        0     30.1    0.349       47
# 767        1       93       70       31        0     30.4    0.315       23
#
#      header9
# 0          1
# 1          0
# ...

# %% [markdown]
# ## dataset from URL

# %%
url=pd.read_csv('http://winterolympicsmedals.com/medals.csv')

# %%
url.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# ## Read Text FIle

# %%
text=pd.read_table('/content/requirements.txt',header=None,names=['text_file'])
text
# Out:
#                  text_file
# 0           appdirs==1.4.3
# 1       certifi==2020.6.20
# 2             click==7.1.2
# 3           distlib==0.3.0
# 4             Flask==1.1.2
# 5        Flask-Cors==3.0.8
# 6         gunicorn==20.0.4
# 7      itsdangerous==1.1.0
# 8           Jinja2==2.11.2
# 9           joblib==0.15.1
# 10       MarkupSafe==1.1.1
# 11           numpy==1.18.1
# 12           pandas==1.0.1
# 13  python-dateutil==2.8.1
# 14            pytz==2019.3
# 15    scikit-learn==0.22.1
# 16            scipy==1.4.1
# 17             six==1.14.0
# 18      virtualenv==20.0.7
# 19         Werkzeug==1.0.1
# 20       wincertstore==0.2

# %% [markdown]
# ## OR using csv

# %%
text1=pd.read_table('/content/requirements.txt',header=None,names=['text_file'])
text1
# Out:
#                  text_file
# 0           appdirs==1.4.3
# 1       certifi==2020.6.20
# 2             click==7.1.2
# 3           distlib==0.3.0
# 4             Flask==1.1.2
# 5        Flask-Cors==3.0.8
# 6         gunicorn==20.0.4
# 7      itsdangerous==1.1.0
# 8           Jinja2==2.11.2
# 9           joblib==0.15.1
# 10       MarkupSafe==1.1.1
# 11           numpy==1.18.1
# 12           pandas==1.0.1
# 13  python-dateutil==2.8.1
# 14            pytz==2019.3
# 15    scikit-learn==0.22.1
# 16            scipy==1.4.1
# 17             six==1.14.0
# 18      virtualenv==20.0.7
# 19         Werkzeug==1.0.1
# 20       wincertstore==0.2

# %% [markdown]
# ## Excel dataset

# %%
excel=pd.read_excel('https://www.eia.gov/dnav/pet/hist_xls/RBRTEd.xls')
excel
# Out:
#     Unnamed: 0                                        Unnamed: 1  \
# 0          NaN                                 Workbook Contents
# 1          NaN  Europe Brent Spot Price FOB (Dollars per Barrel)
# 2          NaN                                               NaN
# 3          NaN    Click worksheet name or tab at bottom for data
# 4          NaN                                    Worksheet Name
# 5          NaN                                            Data 1
# 6          NaN                                               NaN
# 7          NaN                                     Release Date:
# 8          NaN                                Next Release Date:
# 9          NaN                                  Excel File Name:
# 10         NaN                          Available from Web Page:
# 11         NaN                                           Source:
# 12         NaN                                For Help, Contact:
# ...

# %%
pip install xlrd==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Skipping rows while importing

# %%
no_skip=pd.read_excel('/content/Book3.xlsx')
no_skip
# Out:
#      omrrts              Full_Name  Gender            City       Country
# 0     10001       Cornelius Kujawa    Male           Tokyo         Japan
# 1     10002      Patrica Courville  Female  New York Metro           USA
# 2     10003          Sanford Xiong    Male       Sao Paulo        Brazil
# 3     10004           Allen Burrus    Male           Seoul   South Korea
# 4     10005      Kathrine Fritzler  Female     Mexico City        Mexico
# ..      ...                    ...     ...             ...           ...
# 146   10146         Bobby Greening    Male          Dallas           USA
# 147   10147         Johnathon Haug    Male          Boston           USA
# 148   10148            Etta Bosque  Female  Belo Horizonte        Brazil
# 149   10149        Tomas Coppinger    Male        Khartoum         Sudan
# 150   10150           Nanci Bonier  Female          Riyadh  Saudi Arabia
#
# [151 rows x 5 columns]

# %%
skip_row=pd.read_excel('/content/Book3.xlsx',skiprows=4)

# %%
skip_row
# Out:
#      10004           Allen Burrus    Male           Seoul   South Korea
# 0    10005      Kathrine Fritzler  Female     Mexico City        Mexico
# 1    10006           Colin Minter    Male           Osaka         Japan
# 2    10007       Velda Kimberling  Female          Manila   Philippines
# 3    10008            Vernon Addy    Male          Mumbai         India
# 4    10009       Blythe Fleischer  Female           Delhi         India
# ..     ...                    ...     ...             ...           ...
# 142  10146         Bobby Greening    Male          Dallas           USA
# 143  10147         Johnathon Haug    Male          Boston           USA
# 144  10148            Etta Bosque  Female  Belo Horizonte        Brazil
# 145  10149        Tomas Coppinger    Male        Khartoum         Sudan
# 146  10150           Nanci Bonier  Female          Riyadh  Saudi Arabia
#
# [147 rows x 5 columns]

# %% [markdown]
# ## Understand your data descriptive statistics

# %% [markdown]
# ## pick at your data

# %%
data.head(10)# first 10 rows
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %%
data.tail(10) # last 10 rows
# Out:
#      Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 758     1   106    76     0     0  37.5  0.197   26      0
# 759     6   190    92     0     0  35.5  0.278   66      1
# 760     2    88    58    26    16  28.4  0.766   22      0
# 761     9   170    74    31     0  44.0  0.403   43      1
# 762     9    89    62     0     0  22.5  0.142   33      0
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0

# %% [markdown]
# ## Dimension of your data

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# ## Cheking Datatype of each attribute

# %%
data.dtypes
# Out:
# Preg       int64
# Plas       int64
# Pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %% [markdown]
# # Descriptive statistic of your data

# %%
data.describe()
# Out:
#              Preg        Plas        Pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %% [markdown]
# Transpose the result

# %%
data.describe().T
# Out:
#        count        mean         std     min       25%       50%        75%  \
# Preg   768.0    3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# Plas   768.0  120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# Pres   768.0   69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# skin   768.0   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# test   768.0   79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# mass   768.0   31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# pedi   768.0    0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# age    768.0   33.240885   11.760232  21.000  24.00000   29.0000   41.00000
# class  768.0    0.348958    0.476951   0.000   0.00000    0.0000    1.00000
#
#           max
# Preg    17.00
# Plas   199.00
# Pres   122.00
# skin    99.00
# test   846.00
# mass    67.10
# pedi     2.42
# age     81.00
# class    1.00

# %% [markdown]
# ## Class Distribution(classification Only)

# %% [markdown]
# ## class in data set is 0 means no dibities and 1 means is dibities

# %%
data['class'].value_counts()
# Out:
# 0    500
# 1    268
# Name: class, dtype: int64

# %% [markdown]
# ## Correlation b/w attribut

# %%
data.corr(method='pearson') # bydefault pearson
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
data.corr(method='kendall')
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.091323  0.135440 -0.064401 -0.096417  0.004183 -0.029959
# Plas   0.091323  1.000000  0.159961  0.039046  0.163645  0.155862  0.061871
# Pres   0.135440  0.159961  1.000000  0.094868 -0.003682  0.205222  0.019448
# skin  -0.064401  0.039046  0.094868  1.000000  0.420066  0.331532  0.126457
# test  -0.096417  0.163645 -0.003682  0.420066  1.000000  0.141587  0.161652
# mass   0.004183  0.155862  0.205222  0.331532  0.141587  1.000000  0.094644
# pedi  -0.029959  0.061871  0.019448  0.126457  0.161652  0.094644  1.000000
# age    0.458272  0.196510  0.246056 -0.044754 -0.080176  0.088678  0.028042
# class  0.170370  0.390565  0.119206  0.076297  0.058531  0.253676  0.143359
#
#             age     class
# Preg   0.458272  0.170370
# Plas   0.196510  0.390565
# Pres   0.246056  0.119206
# skin  -0.044754  0.076297
# test  -0.080176  0.058531
# mass   0.088678  0.253676
# ...

# %%
data.corr()
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %% [markdown]
# ## Skew of univariant Distribution

# %%
data.skew()
# Out:
# Preg     0.901674
# Plas     0.173754
# Pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %% [markdown]
# Cheking The Missing Values

# %%
data.isnull()
# Out:
#       Preg   Plas   Pres   skin   test   mass   pedi    age  class
# 0    False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 763  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False
# 767  False  False  False  False  False  False  False  False  False
#
# [768 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Preg     0
# Plas     0
# Pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %% [markdown]
# ## Histogram of Dataset

# %%
import matplotlib.pyplot as plt

# %%
data.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# ## Density Plot of Dataset

# %%
data.plot(kind='density',subplots=True,layout=(3,3),sharex=False,figsize=(15,10))
plt.show()

# %% [markdown]
# ## Box and Whisker Plot

# %%
data.plot(kind='box',subplots=True,layout=(3,3),sharex=False,sharey=False,figsize=(15,10))
plt.show()

# %% [markdown]
# # Multivariate plots

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# ## Scatter Matrix (pairplot

# %%
pd.plotting.scatter_matrix(data,figsize=(20,15))
plt.show()
